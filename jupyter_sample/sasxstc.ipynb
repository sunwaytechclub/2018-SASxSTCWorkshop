# %%
import pandas
import seaborn
from matplotlib import pyplot
from pprint import pprint
from scipy import stats
import json

# %%
with open('result.json') as json_data:
    results = json.load(json_data)
    
pprint(results)
# Out:
# {'aa': {'gdp_growth_rate': '2.40',
#         'infant_mortality_rate': 0.0107,
#         'name': 'Aruba',
#         'population_growth_rate': '1.27'},
#  'ac': {'gdp_growth_rate': '2.80',
#         'infant_mortality_rate': 0.0121,
#         'name': 'Antigua and Barbuda',
#         'population_growth_rate': '1.21'},
#  'ae': {'gdp_growth_rate': '0.50',
#         'infant_mortality_rate': 0.01,
#         'name': 'United Arab Emirates',
#         'population_growth_rate': '2.37'},
#  'af': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.11059999999999999,
#         'name': 'Afghanistan',
#         'population_growth_rate': '2.36'},
#  'ag': {'gdp_growth_rate': '2.00',
#         'infant_mortality_rate': 0.019600000000000003,
#         'name': 'Algeria',
#         'population_growth_rate': '1.70'},
#  'aj': {'gdp_growth_rate': '0.10',
#         'infant_mortality_rate': 0.0238,
#         'name': 'Azerbaijan',
#         'population_growth_rate': '0.87'},
#  'al': {'gdp_growth_rate': '3.90',
#         'infant_mortality_rate': 0.0119,
#         'name': 'Albania',
#         'population_growth_rate': '0.31'},
#  'am': {'gdp_growth_rate': '7.50',
#         'infant_mortality_rate': 0.0127,
#         'name': 'Armenia',
#         'population_growth_rate': '-0.21'},
#  'an': {'gdp_growth_rate': '-1.10',
#         'infant_mortality_rate': 0.0036,
#         'name': 'Andorra',
#         'population_growth_rate': '0.03'},
#  'ao': {'gdp_growth_rate': '0.70',
#         'infant_mortality_rate': 0.0676,
#         'name': 'Angola',
#         'population_growth_rate': '3.52'},
#  'aq': {'gdp_growth_rate': '-2.50',
#         'infant_mortality_rate': 0.011300000000000001,
#         'name': 'American Samoa',
#         'population_growth_rate': '-1.30'},
#  'ar': {'gdp_growth_rate': '2.90',
#         'infant_mortality_rate': 0.009800000000000001,
#         'name': 'Argentina',
#         'population_growth_rate': '0.91'},
#  'as': {'gdp_growth_rate': '2.30',
#         'infant_mortality_rate': 0.0043,
#         'name': 'Australia',
#         'population_growth_rate': '1.03'},
#  'au': {'gdp_growth_rate': '2.90',
#         'infant_mortality_rate': 0.0034,
#         'name': 'Austria',
#         'population_growth_rate': '0.47'},
#  'av': {'gdp_growth_rate': '-8.50',
#         'infant_mortality_rate': 0.0033,
#         'name': 'Anguilla',
#         'population_growth_rate': '1.97'},
#  'ba': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.0089,
#         'name': 'Bahrain',
#         'population_growth_rate': '2.26'},
#  'bb': {'gdp_growth_rate': '0.90',
#         'infant_mortality_rate': 0.010199999999999999,
#         'name': 'Barbados',
#         'population_growth_rate': '0.28'},
#  'bc': {'gdp_growth_rate': '2.20',
#         'infant_mortality_rate': 0.0296,
#         'name': 'Botswana',
#         'population_growth_rate': '1.55'},
#  'bd': {'gdp_growth_rate': '-0.10',
#         'infant_mortality_rate': 0.0025,
#         'name': 'Bermuda',
#         'population_growth_rate': '0.45'},
#  'be': {'gdp_growth_rate': '1.70',
#         'infant_mortality_rate': 0.0034,
#         'name': 'Belgium',
#         'population_growth_rate': '0.70'},
#  'bf': {'gdp_growth_rate': '1.30',
#         'infant_mortality_rate': 0.011300000000000001,
#         'name': 'Bahamas, The',
#         'population_growth_rate': '0.81'},
#  'bg': {'gdp_growth_rate': '7.10',
#         'infant_mortality_rate': 0.0317,
#         'name': 'Bangladesh',
#         'population_growth_rate': '1.04'},
#  'bh': {'gdp_growth_rate': '0.80',
#         'infant_mortality_rate': 0.0189,
#         'name': 'Belize',
#         'population_growth_rate': '1.80'},
#  'bk': {'gdp_growth_rate': '2.70',
#         'infant_mortality_rate': 0.0055,
#         'name': 'Bosnia and Herzegovina',
#         'population_growth_rate': '-0.16'},
#  'bl': {'gdp_growth_rate': '4.20',
#         'infant_mortality_rate': 0.0353,
#         'name': 'Bolivia',
#         'population_growth_rate': '1.51'},
#  'bm': {'gdp_growth_rate': '6.70',
#         'infant_mortality_rate': 0.0358,
#         'name': 'Burma',
#         'population_growth_rate': '0.91'},
#  'bn': {'gdp_growth_rate': '5.60',
#         'infant_mortality_rate': 0.0528,
#         'name': 'Benin',
#         'population_growth_rate': '2.71'},
#  'bo': {'gdp_growth_rate': '2.40',
#         'infant_mortality_rate': 0.0036,
#         'name': 'Belarus',
#         'population_growth_rate': '-0.22'},
#  'bp': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.0147,
#         'name': 'Solomon Islands',
#         'population_growth_rate': '1.94'},
#  'br': {'gdp_growth_rate': '1.00',
#         'infant_mortality_rate': 0.0175,
#         'name': 'Brazil',
#         'population_growth_rate': '0.73'},
#  'bt': {'gdp_growth_rate': '6.00',
#         'infant_mortality_rate': 0.032100000000000004,
#         'name': 'Bhutan',
#         'population_growth_rate': '1.07'},
#  'bu': {'gdp_growth_rate': '3.60',
#         'infant_mortality_rate': 0.008400000000000001,
#         'name': 'Bulgaria',
#         'population_growth_rate': '-0.61'},
#  'bx': {'gdp_growth_rate': '0.50',
#         'infant_mortality_rate': 0.0096,
#         'name': 'Brunei',
#         'population_growth_rate': '1.57'},
#  'by': {'gdp_growth_rate': '0.00',
#         'infant_mortality_rate': 0.0588,
#         'name': 'Burundi',
#         'population_growth_rate': '3.25'},
#  'ca': {'gdp_growth_rate': '3.00',
#         'infant_mortality_rate': 0.0045,
#         'name': 'Canada',
#         'population_growth_rate': '0.73'},
#  'cb': {'gdp_growth_rate': '6.90',
#         'infant_mortality_rate': 0.0474,
#         'name': 'Cambodia',
#         'population_growth_rate': '1.52'},
#  'cc': {'infant_mortality_rate': 0.0075,
#         'name': 'Curacao',
#         'population_growth_rate': '0.40'},
#  'cd': {'gdp_growth_rate': '-3.10',
#         'infant_mortality_rate': 0.0854,
#         'name': 'Chad',
#         'population_growth_rate': '1.86'},
#  'ce': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.008400000000000001,
#         'name': 'Sri Lanka',
#         'population_growth_rate': '0.76'},
#  'cf': {'gdp_growth_rate': '-4.60',
#         'infant_mortality_rate': 0.0549,
#         'name': 'Congo, Republic of the',
#         'population_growth_rate': '2.11'},
#  'cg': {'gdp_growth_rate': '3.40',
#         'infant_mortality_rate': 0.0682,
#         'name': 'Congo, Democratic Republic of the',
#         'population_growth_rate': '2.37'},
#  'ch': {'gdp_growth_rate': '6.90',
#         'infant_mortality_rate': 0.012,
#         'name': 'China',
#         'population_growth_rate': '0.41'},
#  'ci': {'gdp_growth_rate': '1.50',
#         'infant_mortality_rate': 0.0066,
#         'name': 'Chile',
#         'population_growth_rate': '0.77'},
#  'cj': {'gdp_growth_rate': '1.70',
#         'infant_mortality_rate': 0.005900000000000001,
#         'name': 'Cayman Islands',
#         'population_growth_rate': '2.01'},
#  'ck': {'gdp_growth_rate': '1.00',
#         'name': 'Cocos (Keeling) Islands',
#         'population_growth_rate': '0.00'},
#  'cm': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.051,
#         'name': 'Cameroon',
#         'population_growth_rate': '2.56'},
#  'cn': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.06,
#         'name': 'Comoros',
#         'population_growth_rate': '1.64'},
#  'co': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.0136,
#         'name': 'Colombia',
#         'population_growth_rate': '0.99'},
#  'cq': {'gdp_growth_rate': '28.60',
#         'infant_mortality_rate': 0.0127,
#         'name': 'Northern Mariana Islands',
#         'population_growth_rate': '-0.51'},
#  'cs': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.008,
#         'name': 'Costa Rica',
#         'population_growth_rate': '1.16'},
#  'ct': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.0863,
#         'name': 'Central African Republic',
#         'population_growth_rate': '2.12'},
#  'cu': {'gdp_growth_rate': '1.60',
#         'infant_mortality_rate': 0.0044,
#         'name': 'Cuba',
#         'population_growth_rate': '-0.29'},
#  'cv': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.0219,
#         'name': 'Cabo Verde',
#         'population_growth_rate': '1.33'},
#  'cw': {'gdp_growth_rate': '0.10',
#         'infant_mortality_rate': 0.013,
#         'name': 'Cook Islands',
#         'population_growth_rate': '-2.79'},
#  'cy': {'gdp_growth_rate': '3.90',
#         'infant_mortality_rate': 0.0079,
#         'name': 'Cyprus',
#         'population_growth_rate': '1.32'},
#  'da': {'gdp_growth_rate': '2.10',
#         'infant_mortality_rate': 0.004,
#         'name': 'Denmark',
#         'population_growth_rate': '0.22'},
#  'dj': {'gdp_growth_rate': '6.70',
#         'infant_mortality_rate': 0.0458,
#         'name': 'Djibouti',
#         'population_growth_rate': '2.16'},
#  'do': {'gdp_growth_rate': '-4.20',
#         'infant_mortality_rate': 0.0106,
#         'name': 'Dominica',
#         'population_growth_rate': '0.18'},
#  'dr': {'gdp_growth_rate': '4.60',
#         'infant_mortality_rate': 0.0175,
#         'name': 'Dominican Republic',
#         'population_growth_rate': '1.18'},
#  'ec': {'gdp_growth_rate': '2.70',
#         'infant_mortality_rate': 0.016399999999999998,
#         'name': 'Ecuador',
#         'population_growth_rate': '1.28'},
#  'ee': {'gdp_growth_rate': '2.30',
#         'infant_mortality_rate': 0.004,
#         'name': 'European Union',
#         'population_growth_rate': '0.23'},
#  'eg': {'gdp_growth_rate': '4.20',
#         'infant_mortality_rate': 0.019,
#         'name': 'Egypt',
#         'population_growth_rate': '2.45'},
#  'ei': {'gdp_growth_rate': '7.80',
#         'infant_mortality_rate': 0.0036,
#         'name': 'Ireland',
#         'population_growth_rate': '1.15'},
#  'ek': {'gdp_growth_rate': '-4.40',
#         'infant_mortality_rate': 0.06520000000000001,
#         'name': 'Equatorial Guinea',
#         'population_growth_rate': '2.44'},
#  'en': {'gdp_growth_rate': '4.90',
#         'infant_mortality_rate': 0.0038,
#         'name': 'Estonia',
#         'population_growth_rate': '-0.57'},
#  'er': {'gdp_growth_rate': '5.00',
#         'infant_mortality_rate': 0.045,
#         'name': 'Eritrea',
#         'population_growth_rate': '0.85'},
#  'es': {'gdp_growth_rate': '2.40',
#         'infant_mortality_rate': 0.016800000000000002,
#         'name': 'El Salvador',
#         'population_growth_rate': '0.25'},
#  'et': {'gdp_growth_rate': '10.90',
#         'infant_mortality_rate': 0.0496,
#         'name': 'Ethiopia',
#         'population_growth_rate': '2.85'},
#  'ez': {'gdp_growth_rate': '4.30',
#         'infant_mortality_rate': 0.0026,
#         'name': 'Czechia',
#         'population_growth_rate': '0.12'},
#  'fi': {'gdp_growth_rate': '3.00',
#         'infant_mortality_rate': 0.0025,
#         'name': 'Finland',
#         'population_growth_rate': '0.36'},
#  'fj': {'gdp_growth_rate': '3.80',
#         'infant_mortality_rate': 0.0095,
#         'name': 'Fiji',
#         'population_growth_rate': '0.60'},
#  'fk': {'gdp_growth_rate': '25.50',
#         'name': 'Falkland Islands (Islas Malvinas)',
#         'population_growth_rate': '0.01'},
#  'fm': {'gdp_growth_rate': '2.00',
#         'infant_mortality_rate': 0.0198,
#         'name': 'Micronesia, Federated States of',
#         'population_growth_rate': '-0.52'},
#  'fo': {'gdp_growth_rate': '5.90',
#         'infant_mortality_rate': 0.0054,
#         'name': 'Faroe Islands',
#         'population_growth_rate': '0.55'},
#  'fp': {'gdp_growth_rate': '2.00',
#         'infant_mortality_rate': 0.0046,
#         'name': 'French Polynesia',
#         'population_growth_rate': '0.88'},
#  'fr': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.0032,
#         'name': 'France',
#         'population_growth_rate': '0.39'},
#  'ga': {'gdp_growth_rate': '3.50',
#         'infant_mortality_rate': 0.060200000000000004,
#         'name': 'Gambia, The',
#         'population_growth_rate': '2.05'},
#  'gb': {'gdp_growth_rate': '0.80',
#         'infant_mortality_rate': 0.0441,
#         'name': 'Gabon',
#         'population_growth_rate': '1.92'},
#  'gg': {'gdp_growth_rate': '4.80',
#         'infant_mortality_rate': 0.0152,
#         'name': 'Georgia',
#         'population_growth_rate': '-0.02'},
#  'gh': {'gdp_growth_rate': '8.40',
#         'infant_mortality_rate': 0.0352,
#         'name': 'Ghana',
#         'population_growth_rate': '2.17'},
#  'gi': {'infant_mortality_rate': 0.005900000000000001,
#         'name': 'Gibraltar',
#         'population_growth_rate': '0.23'},
#  'gj': {'gdp_growth_rate': '3.50',
#         'infant_mortality_rate': 0.009699999999999999,
#         'name': 'Grenada',
#         'population_growth_rate': '0.44'},
#  'gk': {'gdp_growth_rate': '0.40',
#         'infant_mortality_rate': 0.0034,
#         'name': 'Guernsey',
#         'population_growth_rate': '0.30'},
#  'gl': {'gdp_growth_rate': '7.70',
#         'infant_mortality_rate': 0.0089,
#         'name': 'Greenland',
#         'population_growth_rate': '-0.03'},
#  'gm': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.0034,
#         'name': 'Germany',
#         'population_growth_rate': '-0.16'},
#  'gq': {'gdp_growth_rate': '0.40',
#         'infant_mortality_rate': 0.0126,
#         'name': 'Guam',
#         'population_growth_rate': '0.26'},
#  'gr': {'gdp_growth_rate': '1.40',
#         'infant_mortality_rate': 0.0046,
#         'name': 'Greece',
#         'population_growth_rate': '-0.06'},
#  'gt': {'gdp_growth_rate': '2.80',
#         'infant_mortality_rate': 0.0213,
#         'name': 'Guatemala',
#         'population_growth_rate': '1.75'},
#  'gv': {'gdp_growth_rate': '6.70',
#         'infant_mortality_rate': 0.05,
#         'name': 'Guinea',
#         'population_growth_rate': '2.61'},
#  'gy': {'gdp_growth_rate': '2.10',
#         'infant_mortality_rate': 0.0304,
#         'name': 'Guyana',
#         'population_growth_rate': '0.32'},
#  'gz': {'gdp_growth_rate': '-15.20',
#         'infant_mortality_rate': 0.0166,
#         'name': 'Gaza Strip',
#         'population_growth_rate': '2.33'},
#  'ha': {'gdp_growth_rate': '1.20',
#         'infant_mortality_rate': 0.046799999999999994,
#         'name': 'Haiti',
#         'population_growth_rate': '1.34'},
#  'hk': {'gdp_growth_rate': '3.80',
#         'infant_mortality_rate': 0.0027,
#         'name': 'Hong Kong',
#         'population_growth_rate': '0.32'},
#  'ho': {'gdp_growth_rate': '4.80',
#         'infant_mortality_rate': 0.0172,
#         'name': 'Honduras',
#         'population_growth_rate': '1.60'},
#  'hr': {'gdp_growth_rate': '2.80',
#         'infant_mortality_rate': 0.009300000000000001,
#         'name': 'Croatia',
#         'population_growth_rate': '-0.50'},
#  'hu': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.004900000000000001,
#         'name': 'Hungary',
#         'population_growth_rate': '-0.25'},
#  'ic': {'gdp_growth_rate': '3.60',
#         'infant_mortality_rate': 0.0021000000000000003,
#         'name': 'Iceland',
#         'population_growth_rate': '1.13'},
#  'id': {'gdp_growth_rate': '5.10',
#         'infant_mortality_rate': 0.022699999999999998,
#         'name': 'Indonesia',
#         'population_growth_rate': '0.86'},
#  'im': {'gdp_growth_rate': '-8.60',
#         'infant_mortality_rate': 0.004,
#         'name': 'Isle of Man',
#         'population_growth_rate': '0.68'},
#  'in': {'gdp_growth_rate': '6.70',
#         'infant_mortality_rate': 0.0391,
#         'name': 'India',
#         'population_growth_rate': '1.17'},
#  'ir': {'gdp_growth_rate': '4.30',
#         'infant_mortality_rate': 0.0159,
#         'name': 'Iran',
#         'population_growth_rate': '1.24'},
#  'is': {'gdp_growth_rate': '3.30',
#         'infant_mortality_rate': 0.0034,
#         'name': 'Israel',
#         'population_growth_rate': '1.51'},
#  'it': {'gdp_growth_rate': '1.50',
#         'infant_mortality_rate': 0.0033,
#         'name': 'Italy',
#         'population_growth_rate': '0.19'},
#  'iv': {'gdp_growth_rate': '7.80',
#         'infant_mortality_rate': 0.055799999999999995,
#         'name': "Cote d'Ivoire",
#         'population_growth_rate': '1.84'},
#  'iz': {'gdp_growth_rate': '-0.80',
#         'infant_mortality_rate': 0.0375,
#         'name': 'Iraq',
#         'population_growth_rate': '2.55'},
#  'ja': {'gdp_growth_rate': '1.70',
#         'infant_mortality_rate': 0.002,
#         'name': 'Japan',
#         'population_growth_rate': '-0.21'},
#  'je': {'gdp_growth_rate': '1.00',
#         'infant_mortality_rate': 0.0038,
#         'name': 'Jersey',
#         'population_growth_rate': '0.78'},
#  'jm': {'gdp_growth_rate': '1.00',
#         'infant_mortality_rate': 0.0128,
#         'name': 'Jamaica',
#         'population_growth_rate': '0.68'},
#  'jo': {'gdp_growth_rate': '2.30',
#         'infant_mortality_rate': 0.014199999999999999,
#         'name': 'Jordan',
#         'population_growth_rate': '2.05'},
#  'ke': {'gdp_growth_rate': '4.80',
#         'infant_mortality_rate': 0.0371,
#         'name': 'Kenya',
#         'population_growth_rate': '1.69'},
#  'kg': {'gdp_growth_rate': '4.50',
#         'infant_mortality_rate': 0.0259,
#         'name': 'Kyrgyzstan',
#         'population_growth_rate': '1.05'},
#  'kn': {'gdp_growth_rate': '-1.10',
#         'infant_mortality_rate': 0.0221,
#         'name': 'Korea, North',
#         'population_growth_rate': '0.53'},
#  'kr': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.032100000000000004,
#         'name': 'Kiribati',
#         'population_growth_rate': '1.13'},
#  'ks': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.003,
#         'name': 'Korea, South',
#         'population_growth_rate': '0.48'},
#  'kt': {'name': 'Christmas Island', 'population_growth_rate': '1.11'},
#  'ku': {'gdp_growth_rate': '-2.50',
#         'infant_mortality_rate': 0.007,
#         'name': 'Kuwait',
#         'population_growth_rate': '1.46'},
#  'kv': {'gdp_growth_rate': '4.10', 'name': 'Kosovo'},
#  'kz': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.019600000000000003,
#         'name': 'Kazakhstan',
#         'population_growth_rate': '1.04'},
#  'la': {'gdp_growth_rate': '6.80',
#         'infant_mortality_rate': 0.0499,
#         'name': 'Laos',
#         'population_growth_rate': '1.51'},
#  'le': {'gdp_growth_rate': '1.20',
#         'infant_mortality_rate': 0.0074,
#         'name': 'Lebanon',
#         'population_growth_rate': '-1.10'},
#  'lg': {'gdp_growth_rate': '4.50',
#         'infant_mortality_rate': 0.0052,
#         'name': 'Latvia',
#         'population_growth_rate': '-1.08'},
#  'lh': {'gdp_growth_rate': '3.80',
#         'infant_mortality_rate': 0.0038,
#         'name': 'Lithuania',
#         'population_growth_rate': '-1.08'},
#  'li': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.0522,
#         'name': 'Liberia',
#         'population_growth_rate': '2.50'},
#  'lo': {'gdp_growth_rate': '3.40',
#         'infant_mortality_rate': 0.0050999999999999995,
#         'name': 'Slovakia',
#         'population_growth_rate': '-0.01'},
#  'ls': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.004200000000000001,
#         'name': 'Liechtenstein',
#         'population_growth_rate': '0.80'},
#  'lt': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.0461,
#         'name': 'Lesotho',
#         'population_growth_rate': '0.28'},
#  'lu': {'gdp_growth_rate': '3.50',
#         'infant_mortality_rate': 0.0034,
#         'name': 'Luxembourg',
#         'population_growth_rate': '1.98'},
#  'ly': {'gdp_growth_rate': '70.80',
#         'infant_mortality_rate': 0.0108,
#         'name': 'Libya',
#         'population_growth_rate': '1.58'},
#  'ma': {'gdp_growth_rate': '4.10',
#         'infant_mortality_rate': 0.0412,
#         'name': 'Madagascar',
#         'population_growth_rate': '2.50'},
#  'mc': {'gdp_growth_rate': '9.30',
#         'infant_mortality_rate': 0.0031,
#         'name': 'Macau',
#         'population_growth_rate': '0.74'},
#  'md': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.012,
#         'name': 'Moldova',
#         'population_growth_rate': '-1.05'},
#  'mg': {'gdp_growth_rate': '5.10',
#         'infant_mortality_rate': 0.0211,
#         'name': 'Mongolia',
#         'population_growth_rate': '1.18'},
#  'mh': {'gdp_growth_rate': '7.40',
#         'infant_mortality_rate': 0.0123,
#         'name': 'Montserrat',
#         'population_growth_rate': '0.45'},
#  'mi': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.0434,
#         'name': 'Malawi',
#         'population_growth_rate': '3.31'},
#  'mj': {'gdp_growth_rate': '4.20',
#         'name': 'Montenegro',
#         'population_growth_rate': '-0.28'},
#  'mk': {'gdp_growth_rate': '0.00',
#         'infant_mortality_rate': 0.0074,
#         'name': 'Macedonia',
#         'population_growth_rate': '0.17'},
#  'ml': {'gdp_growth_rate': '5.30',
#         'infant_mortality_rate': 0.0695,
#         'name': 'Mali',
#         'population_growth_rate': '3.02'},
#  'mn': {'gdp_growth_rate': '5.40',
#         'infant_mortality_rate': 0.0018,
#         'name': 'Monaco',
#         'population_growth_rate': '0.24'},
#  'mo': {'gdp_growth_rate': '4.20',
#         'infant_mortality_rate': 0.0219,
#         'name': 'Morocco',
#         'population_growth_rate': '0.97'},
#  'mp': {'gdp_growth_rate': '3.90',
#         'infant_mortality_rate': 0.009800000000000001,
#         'name': 'Mauritius',
#         'population_growth_rate': '0.59'},
#  'mr': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.0519,
#         'name': 'Mauritania',
#         'population_growth_rate': '2.17'},
#  'mt': {'gdp_growth_rate': '6.60',
#         'infant_mortality_rate': 0.0035,
#         'name': 'Malta',
#         'population_growth_rate': '0.26'},
#  'mu': {'gdp_growth_rate': '-0.30',
#         'infant_mortality_rate': 0.0128,
#         'name': 'Oman',
#         'population_growth_rate': '2.03'},
#  'mv': {'gdp_growth_rate': '4.80',
#         'infant_mortality_rate': 0.022,
#         'name': 'Maldives',
#         'population_growth_rate': '-0.06'},
#  'mx': {'gdp_growth_rate': '2.00',
#         'infant_mortality_rate': 0.0116,
#         'name': 'Mexico',
#         'population_growth_rate': '1.12'},
#  'my': {'gdp_growth_rate': '5.90',
#         'infant_mortality_rate': 0.0125,
#         'name': 'Malaysia',
#         'population_growth_rate': '1.37'},
#  'mz': {'gdp_growth_rate': '3.00',
#         'infant_mortality_rate': 0.0659,
#         'name': 'Mozambique',
#         'population_growth_rate': '2.46'},
#  'nc': {'gdp_growth_rate': '2.00',
#         'infant_mortality_rate': 0.0052,
#         'name': 'New Caledonia',
#         'population_growth_rate': '1.33'},
#  'ne': {'gdp_growth_rate': '6.20',
#         'name': 'Niue',
#         'population_growth_rate': '-0.03'},
#  'nf': {'name': 'Norfolk Island', 'population_growth_rate': '0.01'},
#  'ng': {'gdp_growth_rate': '5.20',
#         'infant_mortality_rate': 0.08109999999999999,
#         'name': 'Niger',
#         'population_growth_rate': '3.19'},
#  'nh': {'gdp_growth_rate': '4.20',
#         'infant_mortality_rate': 0.0144,
#         'name': 'Vanuatu',
#         'population_growth_rate': '1.85'},
#  'ni': {'gdp_growth_rate': '0.80',
#         'infant_mortality_rate': 0.0698,
#         'name': 'Nigeria',
#         'population_growth_rate': '2.43'},
#  'nl': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.0036,
#         'name': 'Netherlands',
#         'population_growth_rate': '0.39'},
#  'nn': {'gdp_growth_rate': '3.60', 'name': 'Sint Maarten'},
#  'no': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.0025,
#         'name': 'Norway',
#         'population_growth_rate': '1.01'},
#  'np': {'gdp_growth_rate': '7.50',
#         'infant_mortality_rate': 0.027899999999999998,
#         'name': 'Nepal',
#         'population_growth_rate': '1.16'},
#  'nr': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.0078,
#         'name': 'Nauru',
#         'population_growth_rate': '0.53'},
#  'ns': {'gdp_growth_rate': '0.00',
#         'infant_mortality_rate': 0.0245,
#         'name': 'Suriname',
#         'population_growth_rate': '1.02'},
#  'nu': {'gdp_growth_rate': '4.90',
#         'infant_mortality_rate': 0.0183,
#         'name': 'Nicaragua',
#         'population_growth_rate': '0.98'},
#  'nz': {'gdp_growth_rate': '3.00',
#         'infant_mortality_rate': 0.0044,
#         'name': 'New Zealand',
#         'population_growth_rate': '0.79'},
#  'od': {'gdp_growth_rate': '-11.10',
#         'infant_mortality_rate': 0.0628,
#         'name': 'South Sudan',
#         'population_growth_rate': '3.83'},
#  'pa': {'gdp_growth_rate': '4.30',
#         'infant_mortality_rate': 0.018699999999999998,
#         'name': 'Paraguay',
#         'population_growth_rate': '1.18'},
#  'pc': {'name': 'Pitcairn Islands', 'population_growth_rate': '0.00'},
#  'pe': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.0184,
#         'name': 'Peru',
#         'population_growth_rate': '0.95'},
#  'pk': {'gdp_growth_rate': '5.30',
#         'infant_mortality_rate': 0.0521,
#         'name': 'Pakistan',
#         'population_growth_rate': '1.43'},
#  'pl': {'gdp_growth_rate': '4.60',
#         'infant_mortality_rate': 0.0044,
#         'name': 'Poland',
#         'population_growth_rate': '-0.13'},
#  'pm': {'gdp_growth_rate': '5.40',
#         'infant_mortality_rate': 0.0099,
#         'name': 'Panama',
#         'population_growth_rate': '1.27'},
#  'po': {'gdp_growth_rate': '2.70',
#         'infant_mortality_rate': 0.0043,
#         'name': 'Portugal',
#         'population_growth_rate': '0.04'},
#  'pp': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.0363,
#         'name': 'Papua New Guinea',
#         'population_growth_rate': '1.71'},
#  'ps': {'gdp_growth_rate': '-1.00',
#         'infant_mortality_rate': 0.0106,
#         'name': 'Palau',
#         'population_growth_rate': '0.39'},
#  'pu': {'gdp_growth_rate': '5.50',
#         'infant_mortality_rate': 0.0857,
#         'name': 'Guinea-Bissau',
#         'population_growth_rate': '1.86'},
#  'qa': {'gdp_growth_rate': '2.10',
#         'infant_mortality_rate': 0.0062,
#         'name': 'Qatar',
#         'population_growth_rate': '2.27'},
#  'ri': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.0058,
#         'name': 'Serbia',
#         'population_growth_rate': '-0.46'},
#  'rm': {'gdp_growth_rate': '1.90',
#         'infant_mortality_rate': 0.0193,
#         'name': 'Marshall Islands',
#         'population_growth_rate': '1.55'},
#  'ro': {'gdp_growth_rate': '7.00',
#         'infant_mortality_rate': 0.0094,
#         'name': 'Romania',
#         'population_growth_rate': '-0.33'},
#  'rp': {'gdp_growth_rate': '6.70',
#         'infant_mortality_rate': 0.0214,
#         'name': 'Philippines',
#         'population_growth_rate': '1.57'},
#  'rq': {'gdp_growth_rate': '-7.70',
#         'infant_mortality_rate': 0.0064,
#         'name': 'Puerto Rico',
#         'population_growth_rate': '-1.74'},
#  'rs': {'gdp_growth_rate': '1.50',
#         'infant_mortality_rate': 0.0068,
#         'name': 'Russia',
#         'population_growth_rate': '-0.08'},
#  'rw': {'gdp_growth_rate': '6.10',
#         'infant_mortality_rate': 0.0297,
#         'name': 'Rwanda',
#         'population_growth_rate': '2.45'},
#  'sa': {'gdp_growth_rate': '-0.70',
#         'infant_mortality_rate': 0.0132,
#         'name': 'Saudi Arabia',
#         'population_growth_rate': '1.45'},
#  'sb': {'infant_mortality_rate': 0.0065,
#         'name': 'Saint Pierre and Miquelon',
#         'population_growth_rate': '-1.08'},
#  'sc': {'gdp_growth_rate': '2.60',
#         'infant_mortality_rate': 0.008400000000000001,
#         'name': 'Saint Kitts and Nevis',
#         'population_growth_rate': '0.73'},
#  'se': {'gdp_growth_rate': '4.20',
#         'infant_mortality_rate': 0.01,
#         'name': 'Seychelles',
#         'population_growth_rate': '0.77'},
#  'sf': {'gdp_growth_rate': '1.30',
#         'infant_mortality_rate': 0.031,
#         'name': 'South Africa',
#         'population_growth_rate': '0.99'},
#  'sg': {'gdp_growth_rate': '7.20',
#         'infant_mortality_rate': 0.049100000000000005,
#         'name': 'Senegal',
#         'population_growth_rate': '2.39'},
#  'sh': {'infant_mortality_rate': 0.013300000000000001,
#         'name': 'Saint Helena, Ascension, and Tristan da Cunha',
#         'population_growth_rate': '0.18'},
#  'si': {'gdp_growth_rate': '5.00',
#         'infant_mortality_rate': 0.0039,
#         'name': 'Slovenia',
#         'population_growth_rate': '-0.31'},
#  'sk': {'infant_mortality_rate': 0.0081,
#         'name': 'Sint Maarten',
#         'population_growth_rate': '1.42'},
#  'sl': {'gdp_growth_rate': '3.50',
#         'infant_mortality_rate': 0.0684,
#         'name': 'Sierra Leone',
#         'population_growth_rate': '2.38'},
#  'sm': {'gdp_growth_rate': '1.50',
#         'infant_mortality_rate': 0.0043,
#         'name': 'San Marino',
#         'population_growth_rate': '0.74'},
#  'sn': {'gdp_growth_rate': '3.60',
#         'infant_mortality_rate': 0.0024,
#         'name': 'Singapore',
#         'population_growth_rate': '1.82'},
#  'so': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.0948,
#         'name': 'Somalia',
#         'population_growth_rate': '2.00'},
#  'sp': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.0033,
#         'name': 'Spain',
#         'population_growth_rate': '0.78'},
#  'st': {'gdp_growth_rate': '3.00',
#         'infant_mortality_rate': 0.0109,
#         'name': 'Saint Lucia',
#         'population_growth_rate': '0.32'},
#  'su': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.048799999999999996,
#         'name': 'Sudan',
#         'population_growth_rate': '1.64'},
#  'sv': {'name': 'Svalbard', 'population_growth_rate': '-0.03'},
#  'sw': {'gdp_growth_rate': '2.40',
#         'infant_mortality_rate': 0.0026,
#         'name': 'Sweden',
#         'population_growth_rate': '0.81'},
#  'sy': {'infant_mortality_rate': 0.0148, 'name': 'Syria'},
#  'sz': {'gdp_growth_rate': '1.10',
#         'infant_mortality_rate': 0.0036,
#         'name': 'Switzerland',
#         'population_growth_rate': '0.69'},
#  'td': {'gdp_growth_rate': '-2.60',
#         'infant_mortality_rate': 0.0223,
#         'name': 'Trinidad and Tobago',
#         'population_growth_rate': '-0.20'},
#  'th': {'gdp_growth_rate': '3.90',
#         'infant_mortality_rate': 0.0092,
#         'name': 'Thailand',
#         'population_growth_rate': '0.30'},
#  'ti': {'gdp_growth_rate': '7.10',
#         'infant_mortality_rate': 0.0318,
#         'name': 'Tajikistan',
#         'population_growth_rate': '1.62'},
#  'tk': {'gdp_growth_rate': '11.20',
#         'infant_mortality_rate': 0.0101,
#         'name': 'Turks and Caicos Islands',
#         'population_growth_rate': '2.16'},
#  'tl': {'name': 'Tokelau', 'population_growth_rate': '-0.01'},
#  'tn': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.011300000000000001,
#         'name': 'Tonga',
#         'population_growth_rate': '-0.05'},
#  'to': {'gdp_growth_rate': '4.40',
#         'infant_mortality_rate': 0.0422,
#         'name': 'Togo',
#         'population_growth_rate': '2.64'},
#  'tp': {'gdp_growth_rate': '4.00',
#         'infant_mortality_rate': 0.0453,
#         'name': 'Sao Tome and Principe',
#         'population_growth_rate': '1.72'},
#  'ts': {'gdp_growth_rate': '1.90',
#         'infant_mortality_rate': 0.0121,
#         'name': 'Tunisia',
#         'population_growth_rate': '1.01'},
#  'tt': {'gdp_growth_rate': '-0.50',
#         'infant_mortality_rate': 0.0351,
#         'name': 'Timor-Leste',
#         'population_growth_rate': '2.36'},
#  'tu': {'gdp_growth_rate': '7.00',
#         'infant_mortality_rate': 0.0176,
#         'name': 'Turkey',
#         'population_growth_rate': '0.52'},
#  'tv': {'gdp_growth_rate': '3.20',
#         'infant_mortality_rate': 0.029,
#         'name': 'Tuvalu',
#         'population_growth_rate': '0.85'},
#  'tw': {'gdp_growth_rate': '2.80',
#         'infant_mortality_rate': 0.0043,
#         'name': 'Taiwan',
#         'population_growth_rate': '0.17'},
#  'tx': {'gdp_growth_rate': '6.50',
#         'infant_mortality_rate': 0.0343,
#         'name': 'Turkmenistan',
#         'population_growth_rate': '1.12'},
#  'tz': {'gdp_growth_rate': '6.00',
#         'infant_mortality_rate': 0.0399,
#         'name': 'Tanzania',
#         'population_growth_rate': '2.75'},
#  'uc': {'gdp_growth_rate': '3.60', 'name': 'Curacao'},
#  'ug': {'gdp_growth_rate': '4.50',
#         'infant_mortality_rate': 0.056100000000000004,
#         'name': 'Uganda',
#         'population_growth_rate': '3.20'},
#  'uk': {'gdp_growth_rate': '1.80',
#         'infant_mortality_rate': 0.0043,
#         'name': 'United Kingdom',
#         'population_growth_rate': '0.52'},
#  'up': {'gdp_growth_rate': '2.50',
#         'infant_mortality_rate': 0.0078,
#         'name': 'Ukraine',
#         'population_growth_rate': '-0.41'},
#  'us': {'gdp_growth_rate': '2.30',
#         'infant_mortality_rate': 0.0058,
#         'name': 'United States',
#         'population_growth_rate': '0.81'},
#  'uv': {'gdp_growth_rate': '6.40',
#         'infant_mortality_rate': 0.0722,
#         'name': 'Burkina Faso',
#         'population_growth_rate': '3.00'},
#  'uy': {'gdp_growth_rate': '3.10',
#         'infant_mortality_rate': 0.0083,
#         'name': 'Uruguay',
#         'population_growth_rate': '0.27'},
#  'uz': {'gdp_growth_rate': '5.30',
#         'infant_mortality_rate': 0.018,
#         'name': 'Uzbekistan',
#         'population_growth_rate': '0.93'},
#  'vc': {'gdp_growth_rate': '1.00',
#         'infant_mortality_rate': 0.012,
#         'name': 'Saint Vincent and the Grenadines',
#         'population_growth_rate': '-0.25'},
#  've': {'gdp_growth_rate': '-14.00',
#         'infant_mortality_rate': 0.012199999999999999,
#         'name': 'Venezuela',
#         'population_growth_rate': '1.24'},
#  'vi': {'gdp_growth_rate': '2.00',
#         'infant_mortality_rate': 0.0121,
#         'name': 'British Virgin Islands',
#         'population_growth_rate': '2.25'},
#  'vm': {'gdp_growth_rate': '6.80',
#         'infant_mortality_rate': 0.0173,
#         'name': 'Vietnam',
#         'population_growth_rate': '0.93'},
#  'vq': {'gdp_growth_rate': '0.90',
#         'infant_mortality_rate': 0.0079,
#         'name': 'Virgin Islands',
#         'population_growth_rate': '-0.25'},
#  'vt': {'name': 'Holy See (Vatican City)', 'population_growth_rate': '0.00'},
#  'wa': {'gdp_growth_rate': '-1.20',
#         'infant_mortality_rate': 0.0351,
#         'name': 'Namibia',
#         'population_growth_rate': '1.95'},
#  'we': {'gdp_growth_rate': '5.30',
#         'infant_mortality_rate': 0.0141,
#         'name': 'West Bank',
#         'population_growth_rate': '1.84'},
#  'wf': {'infant_mortality_rate': 0.0043,
#         'name': 'Wallis and Futuna',
#         'population_growth_rate': '0.32'},
#  'wi': {'infant_mortality_rate': 0.0519,
#         'name': 'Western Sahara',
#         'population_growth_rate': '2.70'},
#  'ws': {'gdp_growth_rate': '2.40',
#         'infant_mortality_rate': 0.018600000000000002,
#         'name': 'Samoa',
#         'population_growth_rate': '0.60'},
#  'wz': {'gdp_growth_rate': '0.20',
#         'infant_mortality_rate': 0.0484,
#         'name': 'Swaziland',
#         'population_growth_rate': '1.08'},
#  'ym': {'gdp_growth_rate': '-13.80',
#         'infant_mortality_rate': 0.046,
#         'name': 'Yemen',
#         'population_growth_rate': '2.28'},
#  'za': {'gdp_growth_rate': '3.60',
#         'infant_mortality_rate': 0.0611,
#         'name': 'Zambia',
#         'population_growth_rate': '2.93'},
#  'zi': {'gdp_growth_rate': '3.00',
#         'infant_mortality_rate': 0.0327,
#         'name': 'Zimbabwe',
#         'population_growth_rate': '1.56'}}

# %%
country_name = []
population_growth = []
infant_mortality = []
gdp_growth = []

for country_code in list(results.keys()):

    country_name.append(results[country_code]["name"])

    try:
        population_growth.append(float(results[country_code]["population_growth_rate"]))
    except KeyError:
        population_growth.append(None)

    try:
        infant_mortality.append(float(results[country_code]["infant_mortality_rate"]))
    except KeyError:
        infant_mortality.append(None)

    try:
        gdp_growth.append(float(results[country_code]["gdp_growth_rate"]))
    except KeyError:
        gdp_growth.append(None)

country_name
# Out:
# ['South Sudan',
#  'Angola',
#  'Malawi',
#  'Burundi',
#  'Uganda',
#  'Niger',
#  'Mali',
#  'Burkina Faso',
#  'Zambia',
#  'Ethiopia',
#  'Tanzania',
#  'Benin',
#  'Western Sahara',
#  'Togo',
#  'Guinea',
#  'Cameroon',
#  'Iraq',
#  'Madagascar',
#  'Liberia',
#  'Mozambique',
#  'Rwanda',
#  'Egypt',
#  'Equatorial Guinea',
#  'Nigeria',
#  'Senegal',
#  'Sierra Leone',
#  'Congo, Democratic Republic of the',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Timor-Leste',
#  'Gaza Strip',
#  'Yemen',
#  'Qatar',
#  'Bahrain',
#  'British Virgin Islands',
#  'Ghana',
#  'Mauritania',
#  'Turks and Caicos Islands',
#  'Djibouti',
#  'Central African Republic',
#  'Congo, Republic of the',
#  'Gambia, The',
#  'Jordan',
#  'Oman',
#  'Cayman Islands',
#  'Somalia',
#  'Luxembourg',
#  'Anguilla',
#  'Namibia',
#  'Solomon Islands',
#  'Gabon',
#  'Chad',
#  'Guinea-Bissau',
#  'Vanuatu',
#  "Cote d'Ivoire",
#  'West Bank',
#  'Singapore',
#  'Belize',
#  'Guatemala',
#  'Sao Tome and Principe',
#  'Papua New Guinea',
#  'Algeria',
#  'Kenya',
#  'Comoros',
#  'Sudan',
#  'Tajikistan',
#  'Honduras',
#  'Libya',
#  'Brunei',
#  'Philippines',
#  'Zimbabwe',
#  'Botswana',
#  'Marshall Islands',
#  'Cambodia',
#  'Bolivia',
#  'Israel',
#  'Laos',
#  'Kuwait',
#  'Saudi Arabia',
#  'Pakistan',
#  'Sint Maarten',
#  'Malaysia',
#  'Haiti',
#  'Cabo Verde',
#  'New Caledonia',
#  'Cyprus',
#  'Ecuador',
#  'Aruba',
#  'Panama',
#  'Iran',
#  'Venezuela',
#  'Antigua and Barbuda',
#  'Mongolia',
#  'Paraguay',
#  'Dominican Republic',
#  'India',
#  'Nepal',
#  'Costa Rica',
#  'Ireland',
#  'Kiribati',
#  'Iceland',
#  'Turkmenistan',
#  'Mexico',
#  'Christmas Island',
#  'Swaziland',
#  'Bhutan',
#  'Kyrgyzstan',
#  'Bangladesh',
#  'Kazakhstan',
#  'Australia',
#  'Suriname',
#  'Tunisia',
#  'Norway',
#  'South Africa',
#  'Colombia',
#  'Nicaragua',
#  'Morocco',
#  'Peru',
#  'Uzbekistan',
#  'Vietnam',
#  'Argentina',
#  'Burma',
#  'French Polynesia',
#  'Azerbaijan',
#  'Indonesia',
#  'Eritrea',
#  'Tuvalu',
#  'Sweden',
#  'United States',
#  'Bahamas, The',
#  'Liechtenstein',
#  'New Zealand',
#  'Jersey',
#  'Spain',
#  'Chile',
#  'Seychelles',
#  'Sri Lanka',
#  'Macau',
#  'San Marino',
#  'Brazil',
#  'Canada',
#  'Saint Kitts and Nevis',
#  'Belgium',
#  'Switzerland',
#  'Jamaica',
#  'Isle of Man',
#  'Samoa',
#  'Fiji',
#  'Mauritius',
#  'Faroe Islands',
#  'Korea, North',
#  'Nauru',
#  'Turkey',
#  'United Kingdom',
#  'Korea, South',
#  'Austria',
#  'Bermuda',
#  'Montserrat',
#  'Grenada',
#  'China',
#  'Curacao',
#  'Palau',
#  'France',
#  'Netherlands',
#  'Finland',
#  'Hong Kong',
#  'Guyana',
#  'Saint Lucia',
#  'Wallis and Futuna',
#  'Albania',
#  'Thailand',
#  'Guernsey',
#  'Lesotho',
#  'Barbados',
#  'Uruguay',
#  'Malta',
#  'Guam',
#  'El Salvador',
#  'Monaco',
#  'European Union',
#  'Gibraltar',
#  'Denmark',
#  'Italy',
#  'Dominica',
#  'Saint Helena, Ascension, and Tristan da Cunha',
#  'Taiwan',
#  'Macedonia',
#  'Czechia',
#  'Portugal',
#  'Andorra',
#  'Falkland Islands (Islas Malvinas)',
#  'Norfolk Island',
#  'Holy See (Vatican City)',
#  'Pitcairn Islands',
#  'Cocos (Keeling) Islands',
#  'Slovakia',
#  'Tokelau',
#  'Georgia',
#  'Svalbard',
#  'Greenland',
#  'Niue',
#  'Tonga',
#  'Maldives',
#  'Greece',
#  'Russia',
#  'Poland',
#  'Bosnia and Herzegovina',
#  'Germany',
#  'Trinidad and Tobago',
#  'Armenia',
#  'Japan',
#  'Belarus',
#  'Saint Vincent and the Grenadines',
#  'Hungary',
#  'Virgin Islands',
#  'Montenegro',
#  'Cuba',
#  'Slovenia',
#  'Romania',
#  'Ukraine',
#  'Serbia',
#  'Croatia',
#  'Northern Mariana Islands',
#  'Micronesia, Federated States of',
#  'Estonia',
#  'Bulgaria',
#  'Moldova',
#  'Lithuania',
#  'Latvia',
#  'Saint Pierre and Miquelon',
#  'Lebanon',
#  'American Samoa',
#  'Puerto Rico',
#  'Cook Islands',
#  'Syria',
#  'Kosovo',
#  'Curacao',
#  'Sint Maarten']

# %%
population_growth
# Out:
# [3.83,
#  3.52,
#  3.31,
#  3.25,
#  3.2,
#  3.19,
#  3.02,
#  3.0,
#  2.93,
#  2.85,
#  2.75,
#  2.71,
#  2.7,
#  2.64,
#  2.61,
#  2.56,
#  2.55,
#  2.5,
#  2.5,
#  2.46,
#  2.45,
#  2.45,
#  2.44,
#  2.43,
#  2.39,
#  2.38,
#  2.37,
#  2.37,
#  2.36,
#  2.36,
#  2.33,
#  2.28,
#  2.27,
#  2.26,
#  2.25,
#  2.17,
#  2.17,
#  2.16,
#  2.16,
#  2.12,
#  2.11,
#  2.05,
#  2.05,
#  2.03,
#  2.01,
#  2.0,
#  1.98,
#  1.97,
#  1.95,
#  1.94,
#  1.92,
#  1.86,
#  1.86,
#  1.85,
#  1.84,
#  1.84,
#  1.82,
#  1.8,
#  1.75,
#  1.72,
#  1.71,
#  1.7,
#  1.69,
#  1.64,
#  1.64,
#  1.62,
#  1.6,
#  1.58,
#  1.57,
#  1.57,
#  1.56,
#  1.55,
#  1.55,
#  1.52,
#  1.51,
#  1.51,
#  1.51,
#  1.46,
#  1.45,
#  1.43,
#  1.42,
#  1.37,
#  1.34,
#  1.33,
#  1.33,
#  1.32,
#  1.28,
#  1.27,
#  1.27,
#  1.24,
#  1.24,
#  1.21,
#  1.18,
#  1.18,
#  1.18,
#  1.17,
#  1.16,
#  1.16,
#  1.15,
#  1.13,
#  1.13,
#  1.12,
#  1.12,
#  1.11,
#  1.08,
#  1.07,
#  1.05,
#  1.04,
#  1.04,
#  1.03,
#  1.02,
#  1.01,
#  1.01,
#  0.99,
#  0.99,
#  0.98,
#  0.97,
#  0.95,
#  0.93,
#  0.93,
#  0.91,
#  0.91,
#  0.88,
#  0.87,
#  0.86,
#  0.85,
#  0.85,
#  0.81,
#  0.81,
#  0.81,
#  0.8,
#  0.79,
#  0.78,
#  0.78,
#  0.77,
#  0.77,
#  0.76,
#  0.74,
#  0.74,
#  0.73,
#  0.73,
#  0.73,
#  0.7,
#  0.69,
#  0.68,
#  0.68,
#  0.6,
#  0.6,
#  0.59,
#  0.55,
#  0.53,
#  0.53,
#  0.52,
#  0.52,
#  0.48,
#  0.47,
#  0.45,
#  0.45,
#  0.44,
#  0.41,
#  0.4,
#  0.39,
#  0.39,
#  0.39,
#  0.36,
#  0.32,
#  0.32,
#  0.32,
#  0.32,
#  0.31,
#  0.3,
#  0.3,
#  0.28,
#  0.28,
#  0.27,
#  0.26,
#  0.26,
#  0.25,
#  0.24,
#  0.23,
#  0.23,
#  0.22,
#  0.19,
#  0.18,
#  0.18,
#  0.17,
#  0.17,
#  0.12,
#  0.04,
#  0.03,
#  0.01,
#  0.01,
#  0.0,
#  0.0,
#  0.0,
#  -0.01,
#  -0.01,
#  -0.02,
#  -0.03,
#  -0.03,
#  -0.03,
#  -0.05,
#  -0.06,
#  -0.06,
#  -0.08,
#  -0.13,
#  -0.16,
#  -0.16,
#  -0.2,
#  -0.21,
#  -0.21,
#  -0.22,
#  -0.25,
#  -0.25,
#  -0.25,
#  -0.28,
#  -0.29,
#  -0.31,
#  -0.33,
#  -0.41,
#  -0.46,
#  -0.5,
#  -0.51,
#  -0.52,
#  -0.57,
#  -0.61,
#  -1.05,
#  -1.08,
#  -1.08,
#  -1.08,
#  -1.1,
#  -1.3,
#  -1.74,
#  -2.79,
#  None,
#  None,
#  None,
#  None]

# %%
infant_mortality
# Out:
# [0.0628,
#  0.0676,
#  0.0434,
#  0.0588,
#  0.056100000000000004,
#  0.08109999999999999,
#  0.0695,
#  0.0722,
#  0.0611,
#  0.0496,
#  0.0399,
#  0.0528,
#  0.0519,
#  0.0422,
#  0.05,
#  0.051,
#  0.0375,
#  0.0412,
#  0.0522,
#  0.0659,
#  0.0297,
#  0.019,
#  0.06520000000000001,
#  0.0698,
#  0.049100000000000005,
#  0.0684,
#  0.0682,
#  0.01,
#  0.11059999999999999,
#  0.0351,
#  0.0166,
#  0.046,
#  0.0062,
#  0.0089,
#  0.0121,
#  0.0352,
#  0.0519,
#  0.0101,
#  0.0458,
#  0.0863,
#  0.0549,
#  0.060200000000000004,
#  0.014199999999999999,
#  0.0128,
#  0.005900000000000001,
#  0.0948,
#  0.0034,
#  0.0033,
#  0.0351,
#  0.0147,
#  0.0441,
#  0.0854,
#  0.0857,
#  0.0144,
#  0.055799999999999995,
#  0.0141,
#  0.0024,
#  0.0189,
#  0.0213,
#  0.0453,
#  0.0363,
#  0.019600000000000003,
#  0.0371,
#  0.06,
#  0.048799999999999996,
#  0.0318,
#  0.0172,
#  0.0108,
#  0.0096,
#  0.0214,
#  0.0327,
#  0.0296,
#  0.0193,
#  0.0474,
#  0.0353,
#  0.0034,
#  0.0499,
#  0.007,
#  0.0132,
#  0.0521,
#  0.0081,
#  0.0125,
#  0.046799999999999994,
#  0.0219,
#  0.0052,
#  0.0079,
#  0.016399999999999998,
#  0.0107,
#  0.0099,
#  0.0159,
#  0.012199999999999999,
#  0.0121,
#  0.0211,
#  0.018699999999999998,
#  0.0175,
#  0.0391,
#  0.027899999999999998,
#  0.008,
#  0.0036,
#  0.032100000000000004,
#  0.0021000000000000003,
#  0.0343,
#  0.0116,
#  None,
#  0.0484,
#  0.032100000000000004,
#  0.0259,
#  0.0317,
#  0.019600000000000003,
#  0.0043,
#  0.0245,
#  0.0121,
#  0.0025,
#  0.031,
#  0.0136,
#  0.0183,
#  0.0219,
#  0.0184,
#  0.018,
#  0.0173,
#  0.009800000000000001,
#  0.0358,
#  0.0046,
#  0.0238,
#  0.022699999999999998,
#  0.045,
#  0.029,
#  0.0026,
#  0.0058,
#  0.011300000000000001,
#  0.004200000000000001,
#  0.0044,
#  0.0038,
#  0.0033,
#  0.0066,
#  0.01,
#  0.008400000000000001,
#  0.0031,
#  0.0043,
#  0.0175,
#  0.0045,
#  0.008400000000000001,
#  0.0034,
#  0.0036,
#  0.0128,
#  0.004,
#  0.018600000000000002,
#  0.0095,
#  0.009800000000000001,
#  0.0054,
#  0.0221,
#  0.0078,
#  0.0176,
#  0.0043,
#  0.003,
#  0.0034,
#  0.0025,
#  0.0123,
#  0.009699999999999999,
#  0.012,
#  0.0075,
#  0.0106,
#  0.0032,
#  0.0036,
#  0.0025,
#  0.0027,
#  0.0304,
#  0.0109,
#  0.0043,
#  0.0119,
#  0.0092,
#  0.0034,
#  0.0461,
#  0.010199999999999999,
#  0.0083,
#  0.0035,
#  0.0126,
#  0.016800000000000002,
#  0.0018,
#  0.004,
#  0.005900000000000001,
#  0.004,
#  0.0033,
#  0.0106,
#  0.013300000000000001,
#  0.0043,
#  0.0074,
#  0.0026,
#  0.0043,
#  0.0036,
#  None,
#  None,
#  None,
#  None,
#  None,
#  0.0050999999999999995,
#  None,
#  0.0152,
#  None,
#  0.0089,
#  None,
#  0.011300000000000001,
#  0.022,
#  0.0046,
#  0.0068,
#  0.0044,
#  0.0055,
#  0.0034,
#  0.0223,
#  0.0127,
#  0.002,
#  0.0036,
#  0.012,
#  0.004900000000000001,
#  0.0079,
#  None,
#  0.0044,
#  0.0039,
#  0.0094,
#  0.0078,
#  0.0058,
#  0.009300000000000001,
#  0.0127,
#  0.0198,
#  0.0038,
#  0.008400000000000001,
#  0.012,
#  0.0038,
#  0.0052,
#  0.0065,
#  0.0074,
#  0.011300000000000001,
#  0.0064,
#  0.013,
#  0.0148,
#  None,
#  None,
#  None]

# %%
gdp_growth
# Out:
# [-11.1,
#  0.7,
#  4.0,
#  0.0,
#  4.5,
#  5.2,
#  5.3,
#  6.4,
#  3.6,
#  10.9,
#  6.0,
#  5.6,
#  None,
#  4.4,
#  6.7,
#  3.2,
#  -0.8,
#  4.1,
#  2.5,
#  3.0,
#  6.1,
#  4.2,
#  -4.4,
#  0.8,
#  7.2,
#  3.5,
#  3.4,
#  0.5,
#  2.5,
#  -0.5,
#  -15.2,
#  -13.8,
#  2.1,
#  3.2,
#  2.0,
#  8.4,
#  3.2,
#  11.2,
#  6.7,
#  4.0,
#  -4.6,
#  3.5,
#  2.3,
#  -0.3,
#  1.7,
#  1.8,
#  3.5,
#  -8.5,
#  -1.2,
#  3.2,
#  0.8,
#  -3.1,
#  5.5,
#  4.2,
#  7.8,
#  5.3,
#  3.6,
#  0.8,
#  2.8,
#  4.0,
#  2.5,
#  2.0,
#  4.8,
#  2.5,
#  3.2,
#  7.1,
#  4.8,
#  70.8,
#  0.5,
#  6.7,
#  3.0,
#  2.2,
#  1.9,
#  6.9,
#  4.2,
#  3.3,
#  6.8,
#  -2.5,
#  -0.7,
#  5.3,
#  None,
#  5.9,
#  1.2,
#  4.0,
#  2.0,
#  3.9,
#  2.7,
#  2.4,
#  5.4,
#  4.3,
#  -14.0,
#  2.8,
#  5.1,
#  4.3,
#  4.6,
#  6.7,
#  7.5,
#  3.2,
#  7.8,
#  3.1,
#  3.6,
#  6.5,
#  2.0,
#  None,
#  0.2,
#  6.0,
#  4.5,
#  7.1,
#  4.0,
#  2.3,
#  0.0,
#  1.9,
#  1.8,
#  1.3,
#  1.8,
#  4.9,
#  4.2,
#  2.5,
#  5.3,
#  6.8,
#  2.9,
#  6.7,
#  2.0,
#  0.1,
#  5.1,
#  5.0,
#  3.2,
#  2.4,
#  2.3,
#  1.3,
#  1.8,
#  3.0,
#  1.0,
#  3.1,
#  1.5,
#  4.2,
#  3.1,
#  9.3,
#  1.5,
#  1.0,
#  3.0,
#  2.6,
#  1.7,
#  1.1,
#  1.0,
#  -8.6,
#  2.4,
#  3.8,
#  3.9,
#  5.9,
#  -1.1,
#  4.0,
#  7.0,
#  1.8,
#  3.1,
#  2.9,
#  -0.1,
#  7.4,
#  3.5,
#  6.9,
#  None,
#  -1.0,
#  1.8,
#  3.1,
#  3.0,
#  3.8,
#  2.1,
#  3.0,
#  None,
#  3.9,
#  3.9,
#  0.4,
#  3.1,
#  0.9,
#  3.1,
#  6.6,
#  0.4,
#  2.4,
#  5.4,
#  2.3,
#  None,
#  2.1,
#  1.5,
#  -4.2,
#  None,
#  2.8,
#  0.0,
#  4.3,
#  2.7,
#  -1.1,
#  25.5,
#  None,
#  None,
#  None,
#  1.0,
#  3.4,
#  None,
#  4.8,
#  None,
#  7.7,
#  6.2,
#  3.1,
#  4.8,
#  1.4,
#  1.5,
#  4.6,
#  2.7,
#  2.5,
#  -2.6,
#  7.5,
#  1.7,
#  2.4,
#  1.0,
#  4.0,
#  0.9,
#  4.2,
#  1.6,
#  5.0,
#  7.0,
#  2.5,
#  1.8,
#  2.8,
#  28.6,
#  2.0,
#  4.9,
#  3.6,
#  4.0,
#  3.8,
#  4.5,
#  None,
#  1.2,
#  -2.5,
#  -7.7,
#  0.1,
#  None,
#  4.1,
#  3.6,
#  3.6]

# %%
data = pandas.DataFrame(
    {
        "gdp_growth": gdp_growth,
        "infant_mortality": infant_mortality,
        "population_growth": population_growth
    },
    index=country_name
)
data
# Out:
#                                    gdp_growth  infant_mortality  \
# South Sudan                             -11.1            0.0628
# Angola                                    0.7            0.0676
# Malawi                                    4.0            0.0434
# Burundi                                   0.0            0.0588
# Uganda                                    4.5            0.0561
# Niger                                     5.2            0.0811
# Mali                                      5.3            0.0695
# Burkina Faso                              6.4            0.0722
# Zambia                                    3.6            0.0611
# Ethiopia                                 10.9            0.0496
# Tanzania                                  6.0            0.0399
# Benin                                     5.6            0.0528
# Western Sahara                            NaN            0.0519
# Togo                                      4.4            0.0422
# Guinea                                    6.7            0.0500
# Cameroon                                  3.2            0.0510
# Iraq                                     -0.8            0.0375
# Madagascar                                4.1            0.0412
# Liberia                                   2.5            0.0522
# Mozambique                                3.0            0.0659
# Rwanda                                    6.1            0.0297
# Egypt                                     4.2            0.0190
# Equatorial Guinea                        -4.4            0.0652
# Nigeria                                   0.8            0.0698
# Senegal                                   7.2            0.0491
# Sierra Leone                              3.5            0.0684
# Congo, Democratic Republic of the         3.4            0.0682
# United Arab Emirates                      0.5            0.0100
# Afghanistan                               2.5            0.1106
# Timor-Leste                              -0.5            0.0351
# ...                                       ...               ...
# Trinidad and Tobago                      -2.6            0.0223
# Armenia                                   7.5            0.0127
# Japan                                     1.7            0.0020
# Belarus                                   2.4            0.0036
# Saint Vincent and the Grenadines          1.0            0.0120
# Hungary                                   4.0            0.0049
# Virgin Islands                            0.9            0.0079
# Montenegro                                4.2               NaN
# Cuba                                      1.6            0.0044
# Slovenia                                  5.0            0.0039
# Romania                                   7.0            0.0094
# Ukraine                                   2.5            0.0078
# Serbia                                    1.8            0.0058
# Croatia                                   2.8            0.0093
# Northern Mariana Islands                 28.6            0.0127
# Micronesia, Federated States of           2.0            0.0198
# Estonia                                   4.9            0.0038
# Bulgaria                                  3.6            0.0084
# Moldova                                   4.0            0.0120
# Lithuania                                 3.8            0.0038
# Latvia                                    4.5            0.0052
# Saint Pierre and Miquelon                 NaN            0.0065
# Lebanon                                   1.2            0.0074
# American Samoa                           -2.5            0.0113
# Puerto Rico                              -7.7            0.0064
# Cook Islands                              0.1            0.0130
# Syria                                     NaN            0.0148
# Kosovo                                    4.1               NaN
# Curacao                                   3.6               NaN
# Sint Maarten                              3.6               NaN
#
#                                    population_growth
# South Sudan                                     3.83
# Angola                                          3.52
# Malawi                                          3.31
# Burundi                                         3.25
# Uganda                                          3.20
# Niger                                           3.19
# Mali                                            3.02
# Burkina Faso                                    3.00
# Zambia                                          2.93
# Ethiopia                                        2.85
# Tanzania                                        2.75
# Benin                                           2.71
# Western Sahara                                  2.70
# Togo                                            2.64
# Guinea                                          2.61
# Cameroon                                        2.56
# Iraq                                            2.55
# Madagascar                                      2.50
# Liberia                                         2.50
# Mozambique                                      2.46
# Rwanda                                          2.45
# Egypt                                           2.45
# Equatorial Guinea                               2.44
# Nigeria                                         2.43
# Senegal                                         2.39
# Sierra Leone                                    2.38
# Congo, Democratic Republic of the               2.37
# United Arab Emirates                            2.37
# Afghanistan                                     2.36
# Timor-Leste                                     2.36
# ...                                              ...
# Trinidad and Tobago                            -0.20
# Armenia                                        -0.21
# Japan                                          -0.21
# Belarus                                        -0.22
# Saint Vincent and the Grenadines               -0.25
# Hungary                                        -0.25
# Virgin Islands                                 -0.25
# Montenegro                                     -0.28
# Cuba                                           -0.29
# Slovenia                                       -0.31
# Romania                                        -0.33
# Ukraine                                        -0.41
# Serbia                                         -0.46
# Croatia                                        -0.50
# Northern Mariana Islands                       -0.51
# Micronesia, Federated States of                -0.52
# Estonia                                        -0.57
# Bulgaria                                       -0.61
# Moldova                                        -1.05
# Lithuania                                      -1.08
# Latvia                                         -1.08
# Saint Pierre and Miquelon                      -1.08
# Lebanon                                        -1.10
# American Samoa                                 -1.30
# Puerto Rico                                    -1.74
# Cook Islands                                   -2.79
# Syria                                            NaN
# Kosovo                                           NaN
# Curacao                                          NaN
# Sint Maarten                                     NaN
#
# [238 rows x 3 columns]

# %%
data = data.dropna(how='any')
data
# Out:
#                                    gdp_growth  infant_mortality  \
# South Sudan                             -11.1            0.0628
# Angola                                    0.7            0.0676
# Malawi                                    4.0            0.0434
# Burundi                                   0.0            0.0588
# Uganda                                    4.5            0.0561
# Niger                                     5.2            0.0811
# Mali                                      5.3            0.0695
# Burkina Faso                              6.4            0.0722
# Zambia                                    3.6            0.0611
# Ethiopia                                 10.9            0.0496
# Tanzania                                  6.0            0.0399
# Benin                                     5.6            0.0528
# Togo                                      4.4            0.0422
# Guinea                                    6.7            0.0500
# Cameroon                                  3.2            0.0510
# Iraq                                     -0.8            0.0375
# Madagascar                                4.1            0.0412
# Liberia                                   2.5            0.0522
# Mozambique                                3.0            0.0659
# Rwanda                                    6.1            0.0297
# Egypt                                     4.2            0.0190
# Equatorial Guinea                        -4.4            0.0652
# Nigeria                                   0.8            0.0698
# Senegal                                   7.2            0.0491
# Sierra Leone                              3.5            0.0684
# Congo, Democratic Republic of the         3.4            0.0682
# United Arab Emirates                      0.5            0.0100
# Afghanistan                               2.5            0.1106
# Timor-Leste                              -0.5            0.0351
# Gaza Strip                              -15.2            0.0166
# ...                                       ...               ...
# Maldives                                  4.8            0.0220
# Greece                                    1.4            0.0046
# Russia                                    1.5            0.0068
# Poland                                    4.6            0.0044
# Bosnia and Herzegovina                    2.7            0.0055
# Germany                                   2.5            0.0034
# Trinidad and Tobago                      -2.6            0.0223
# Armenia                                   7.5            0.0127
# Japan                                     1.7            0.0020
# Belarus                                   2.4            0.0036
# Saint Vincent and the Grenadines          1.0            0.0120
# Hungary                                   4.0            0.0049
# Virgin Islands                            0.9            0.0079
# Cuba                                      1.6            0.0044
# Slovenia                                  5.0            0.0039
# Romania                                   7.0            0.0094
# Ukraine                                   2.5            0.0078
# Serbia                                    1.8            0.0058
# Croatia                                   2.8            0.0093
# Northern Mariana Islands                 28.6            0.0127
# Micronesia, Federated States of           2.0            0.0198
# Estonia                                   4.9            0.0038
# Bulgaria                                  3.6            0.0084
# Moldova                                   4.0            0.0120
# Lithuania                                 3.8            0.0038
# Latvia                                    4.5            0.0052
# Lebanon                                   1.2            0.0074
# American Samoa                           -2.5            0.0113
# Puerto Rico                              -7.7            0.0064
# Cook Islands                              0.1            0.0130
#
#                                    population_growth
# South Sudan                                     3.83
# Angola                                          3.52
# Malawi                                          3.31
# Burundi                                         3.25
# Uganda                                          3.20
# Niger                                           3.19
# Mali                                            3.02
# Burkina Faso                                    3.00
# Zambia                                          2.93
# Ethiopia                                        2.85
# Tanzania                                        2.75
# Benin                                           2.71
# Togo                                            2.64
# Guinea                                          2.61
# Cameroon                                        2.56
# Iraq                                            2.55
# Madagascar                                      2.50
# Liberia                                         2.50
# Mozambique                                      2.46
# Rwanda                                          2.45
# Egypt                                           2.45
# Equatorial Guinea                               2.44
# Nigeria                                         2.43
# Senegal                                         2.39
# Sierra Leone                                    2.38
# Congo, Democratic Republic of the               2.37
# United Arab Emirates                            2.37
# Afghanistan                                     2.36
# Timor-Leste                                     2.36
# Gaza Strip                                      2.33
# ...                                              ...
# Maldives                                       -0.06
# Greece                                         -0.06
# Russia                                         -0.08
# Poland                                         -0.13
# Bosnia and Herzegovina                         -0.16
# Germany                                        -0.16
# Trinidad and Tobago                            -0.20
# Armenia                                        -0.21
# Japan                                          -0.21
# Belarus                                        -0.22
# Saint Vincent and the Grenadines               -0.25
# Hungary                                        -0.25
# Virgin Islands                                 -0.25
# Cuba                                           -0.29
# Slovenia                                       -0.31
# Romania                                        -0.33
# Ukraine                                        -0.41
# Serbia                                         -0.46
# Croatia                                        -0.50
# Northern Mariana Islands                       -0.51
# Micronesia, Federated States of                -0.52
# Estonia                                        -0.57
# Bulgaria                                       -0.61
# Moldova                                        -1.05
# Lithuania                                      -1.08
# Latvia                                         -1.08
# Lebanon                                        -1.10
# American Samoa                                 -1.30
# Puerto Rico                                    -1.74
# Cook Islands                                   -2.79
#
# [217 rows x 3 columns]

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(data["infant_mortality"].tolist(), data["population_growth"].tolist())

seaborn.jointplot(x="infant_mortality", y="population_growth", data=data,
                  kind="reg", stat_func=stats.pearsonr)
pyplot.annotate("y={0:.1f}x+{1:.1f}".format(slope, intercept), xy=(0.05, 0.95), xycoords='axes fraction')
pyplot.show()
# Out:
# /home/gaara/.virtualenvs/sasxstc/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/gaara/.virtualenvs/sasxstc/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))
